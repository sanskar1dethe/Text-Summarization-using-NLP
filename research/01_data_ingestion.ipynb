# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Admin\\Desktop\\source code\\Ttext summarizattion agen using nlp'

# %%
os.chdir('Text-Summarization-using-NLP')

# %%
# %pwd
# Out:
# 'c:\\Users\\Admin\\Desktop\\source code\\Ttext summarizattion agen using nlp\\Text-Summarization-using-NLP'

# %%
from dataclasses import dataclass   
from pathlib import Path

@dataclass(frozen=True) 
class DataIngestionConfig: 
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "src")))

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Admin\Desktop\source code\Ttext summarizattion agen using nlp\TextSumEnv\Scripts\python.exe

# %%
from textSummarizer.utils import *
from textSummarizer.utils.common import read_yaml, create_directories
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 2
#       1 from textSummarizer.utils import *
# ----> 2 from textSummarizer.utils.common import read_yaml, create_directories
#
# File c:\Users\Admin\Desktop\source code\Ttext summarizattion agen using nlp\Text-Summarization-using-NLP\src\textSummarizer\utils\common.py:2
#       1 import os
# ----> 2 from box.exceptions import BoxValueError
#       3 import yaml
#       4 from textSummarizer.logging import logger
#
# ModuleNotFoundError: No module named 'box'
